# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51329/compitative_programming/blob/main/week_2(dynamic%20programming).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fibonacci(n, dp):
    if n <= 1:
        return n

    if dp[n] != -1:
        return dp[n]

    dp[n] = fibonacci(n - 1, dp) + fibonacci(n - 2, dp)
    return dp[n]
n = int(input())
dp = [-1] * (n + 1)
print(fibonacci(n, dp))
# Out:
# 10
# 55
